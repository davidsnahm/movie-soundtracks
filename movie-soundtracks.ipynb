# %%
import numpy as np
import pandas as pd

# %%
data_path = "./data/"

# %%
df = pd.read_csv(data_path + "tracks_features.csv")

# %%
all_ost_songs = df[df['album'].str.contains("Original Motion Picture Soundtrack")].album
albums = all_ost_songs.groupby(all_ost_songs).size()

# %%
albums
# Out:
# album
# "Make the Yuletide Gay" Original Motion Picture Soundtrack         15
# 1/1 (Original Motion Picture Soundtrack)                           15
# 3 In The Attic (Original Motion Picture Soundtrack)                 6
# 300: Rise of an Empire (Original Motion Picture Soundtrack)        16
# 3022 (Original Motion Picture Soundtrack)                          19
#                                                                    ..
# Westender (Original Motion Picture Soundtrack)                     24
# What We Left Behind: Original Motion Picture Soundtrack            32
# Words on Bathroom Walls (Original Motion Picture Soundtrack)       19
# X-Men: Apocalypse (Original Motion Picture Soundtrack)             25
# X-Men: Days of Future Past (Original Motion Picture Soundtrack)    22
# Name: album, Length: 346, dtype: int64

# %%
df[df['album'].str.contains("Original Motion Picture Soundtrack")]
# Out:
#                              id  \
# 3850     7t5Sj3qqT1nUON0ffHxvaP
# 3851     3Dwmggfw8VvvlnjYgvJQgb
# 3852     7aboA3XDf0kXkfjToM8VO6
# 3853     5zWrkqfRv0NNUJhHwjMZGm
# 3854     1RCShzrOfJoW9wmkPXSSEO
# ...                         ...
# 1202998  00wfdVaQuZ7CUbnikzd2zT
# 1202999  5fBbkWcsvwoeI2u5ifhK5b
# 1203000  6FlbPRpFDUtSxK6Y9sTLLW
# 1203001  4YWUbIRmC54ch8FPimIJoy
# 1203002  2bopVKy5e4TUcASCFluJAK
#
#                                                    name  \
# 3850                                       I'm Your Man
# 3851                                         Main Title
# 3852                                       Feelin' Free
# 3853                                   Snow Dome Dreams
# 3854                                    Bathing Blossom
# ...                                                 ...
# 1202998   Prom Hallucinations - Words on Bathroom Walls
# 1202999   If Walls Could Talk - Words on Bathroom Walls
# 1203000                Letter - Words on Bathroom Walls
# ...

# %%
df.shape
# Out:
# (1204025, 24)
